# %%
from tradier import *
import copy

# %%
help(OptionsOrder)
# Out:
# Help on class OptionsOrder in module tradier:
#
# class OptionsOrder(Tradier)
#  |  OptionsOrder(account_number, auth_token)
#  |
#  |  Method resolution order:
#  |      OptionsOrder
#  |      Tradier
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, account_number, auth_token)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  bear_call_spread(self, underlying, option0, quantity0, option1, quantity1, duration='day')
#  |      Bear call spread example:
#  |              • XYZ @ $50/share
#  |              • Pr(XYZ < $55/share) > .50
#  |              • Legs
#  |                      • Short Call with K1 ≥ S (e.g. K1=55 > S=50) and receive $3 premium
#  |                      • Long Call with K2 > K1 ≥ S (e.g. K2=60 > K1=55 ≥ S=50) and pay $1 premium
#  |              • Expiry t=T
#  |                      • If S(T) < K1 -> payoff = premium differential
#  |                      • If K1 < S(T) < K2
# ...

# %%
help(EquityOrder)
# Out:
# Help on class EquityOrder in module tradier:
#
# class EquityOrder(Tradier)
#  |  EquityOrder(account_number, auth_token)
#  |
#  |  Method resolution order:
#  |      EquityOrder
#  |      Tradier
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, account_number, auth_token)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  order(self, symbol, side, quantity, order_type, duration='day', limit_price=False, stop_price=False)
#  |      Example of how to run:
#  |              >>> eo = EquityOrder(ACCOUNT_NUMBER, AUTH_TOKEN)
#  |              >>> eo.order(symbol='QQQ', side='buy', quantity=10, order_type='market', duration='gtc');
#  |              {'order': {'id': 8256590, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from Tradier:
#  |
#  |  __dict__
# ...

# %%
dir()
# Out:
# ['ACCOUNT_NUMBER',
#  'AUTH_TOKEN',
#  'Account',
#  'EquityOrder',
#  'In',
#  'OptionsData',
#  'OptionsOrder',
#  'Out',
#  'Quotes',
#  'Tradier',
#  '_',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__session__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i2',
#  '_i3',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'account',
#  'datetime',
#  'dotenv',
#  'exit',
#  'get_ipython',
#  'np',
#  'open',
#  'options',
#  'options_order',
#  'os',
#  'pd',
#  'quit',
#  'quotes',
#  're',
#  'requests',
#  'schedule',
#  'time',
#  'timedelta']

# %%
eo = EquityOrder(ACCOUNT_NUMBER, AUTH_TOKEN)
eo.order(symbol='QQQ', side='buy', quantity=10, order_type='market', duration='gtc')
# Out:
# {'order': {'id': 8355788,
#   'status': 'ok',
#   'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}

# %%
account.get_orders()
# Out:
#         id    type symbol side  quantity   status duration  avg_fill_price  \
# 0  8355788  market    QQQ  buy      10.0  pending      gtc             0.0
#
#    exec_quantity  last_fill_price  last_fill_quantity  remaining_quantity  \
# 0            0.0              0.0                 0.0                10.0
#
#                 create_date          transaction_date   class
# 0  2023-10-01T18:23:45.094Z  2023-10-01T18:23:45.165Z  equity

# %%
help(quotes)
# Out:
# Help on Quotes in module tradier object:
#
# class Quotes(Tradier)
#  |  Quotes(account_number, auth_token)
#  |
#  |  Method resolution order:
#  |      Quotes
#  |      Tradier
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, account_number, auth_token)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  get_historical_quotes(self, symbol, interval='daily', start_date=False, end_date=False)
#  |      Fetch historical stock data for a given symbol from the Tradier Account API.
#  |
#  |      This function makes a GET request to the Tradier Account API to retrieve historical stock
#  |      data for a specified symbol within a specified time interval.
#  |
#  |      Args:
#  |              symbol (str): The trading symbol of the stock (e.g., 'AAPL', 'MSFT') for which you want
#  |                            to retrieve historical data.
# ...

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasets/s-and-p-500-companies/main/data/constituents.csv')
df.head()

sym_list = []

#for l in df:
#    sym_list.append(l[0])

# %%
df['Symbol']
# Out:
# 0       MMM
# 1       AOS
# 2       ABT
# 3      ABBV
# 4       ACN
#        ...
# 498     YUM
# 499    ZBRA
# 500     ZBH
# 501    ZION
# 502     ZTS
# Name: Symbol, Length: 503, dtype: object

# %%
df2 = quotes.get_historical_quotes('CF', interval = 'monthly', start_date = "2022-10-01")
df2
# Out:
#           date    open     high      low   close    volume
# 0   2022-10-01  101.04  110.590  97.2200  106.26  51537870
# 1   2022-11-01  108.00  112.440  95.4356  108.19  59697249
# 2   2022-12-01  108.60  108.870  84.4700   85.20  48329504
# 3   2023-01-01   84.69   88.080  80.3200   84.70  59981654
# 4   2023-02-01   84.01   91.230  81.1000   85.89  55812424
# 5   2023-03-01   85.79   87.430  67.9500   72.49  68887921
# 6   2023-04-01   73.75   78.660  68.6700   71.58  44048312
# 7   2023-05-01   71.80   76.170  60.4400   61.51  64917053
# 8   2023-06-01   62.00   73.510  60.0800   69.42  57904747
# 9   2023-07-01   69.35   82.605  67.9700   82.08  45052460
# 10  2023-08-01   82.09   84.300  72.4000   77.07  46186615
# 11  2023-09-01   78.00   87.900  78.0000   85.74  48095746

# %%
tap = copy.deepcopy(df2)
tap
# Out:
#           date    open     high      low   close    volume
# 0   2022-10-01  101.04  110.590  97.2200  106.26  51537870
# 1   2022-11-01  108.00  112.440  95.4356  108.19  59697249
# 2   2022-12-01  108.60  108.870  84.4700   85.20  48329504
# 3   2023-01-01   84.69   88.080  80.3200   84.70  59981654
# 4   2023-02-01   84.01   91.230  81.1000   85.89  55812424
# 5   2023-03-01   85.79   87.430  67.9500   72.49  68887921
# 6   2023-04-01   73.75   78.660  68.6700   71.58  44048312
# 7   2023-05-01   71.80   76.170  60.4400   61.51  64917053
# 8   2023-06-01   62.00   73.510  60.0800   69.42  57904747
# 9   2023-07-01   69.35   82.605  67.9700   82.08  45052460
# 10  2023-08-01   82.09   84.300  72.4000   77.07  46186615
# 11  2023-09-01   78.00   87.900  78.0000   85.74  48095746

# %%
tap['profitable'] = ((tap['close']-tap['open'])>0).astype(int)
tap['vol_change'] = tap['volume'].diff()
tap
# Out:
#           date    open     high      low   close    volume  profitable  \
# 0   2022-10-01  101.04  110.590  97.2200  106.26  51537870           1
# 1   2022-11-01  108.00  112.440  95.4356  108.19  59697249           1
# 2   2022-12-01  108.60  108.870  84.4700   85.20  48329504           0
# 3   2023-01-01   84.69   88.080  80.3200   84.70  59981654           1
# 4   2023-02-01   84.01   91.230  81.1000   85.89  55812424           1
# 5   2023-03-01   85.79   87.430  67.9500   72.49  68887921           0
# 6   2023-04-01   73.75   78.660  68.6700   71.58  44048312           0
# 7   2023-05-01   71.80   76.170  60.4400   61.51  64917053           0
# 8   2023-06-01   62.00   73.510  60.0800   69.42  57904747           1
# 9   2023-07-01   69.35   82.605  67.9700   82.08  45052460           1
# 10  2023-08-01   82.09   84.300  72.4000   77.07  46186615           0
# 11  2023-09-01   78.00   87.900  78.0000   85.74  48095746           1
#
#     vol_change
# 0          NaN
# ...

# %%
tap['volume'].diff()[1]
# Out:
# 8159379.0
